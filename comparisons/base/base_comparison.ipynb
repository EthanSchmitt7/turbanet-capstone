# %%
from time import time

import jax
import jax.numpy as jnp
import jax.random as jr
import numpy as np
import optax
import torch
import torch.nn as nn
from flax import linen
from jax.lib import xla_bridge
from turbanet import TurbaTrainState
import altair as alt
import pandas as pd

# %% [markdown]
# # Inputs

# %%
# GENERAL INPUTS
GPU = False

# NETWORK SHAPE INPUTS
hidden_size = 8
num_layers = 3

# TRAINING INPUTS
swarm_size = 1
epochs = 10000
lr = 1e-3
dataset_size = 100

# %%
# Set numpy/torch/flax seeds
seed = 0
np.random.seed(seed)
torch.manual_seed(seed)

# %% [markdown]
# # Create Data

# %%
# Create random data
def make_spirals(n_samples, noise_std=0.0, rotations=1.0):
    ts = jnp.linspace(0, 1, n_samples)
    rs = ts**0.5
    thetas = rs * rotations * 2 * np.pi
    signs = np.random.randint(0, 2, (n_samples,)) * 2 - 1
    labels = (signs > 0).astype(int)

    xs = rs * signs * jnp.cos(thetas) + np.random.randn(n_samples) * noise_std
    ys = rs * signs * jnp.sin(thetas) + np.random.randn(n_samples) * noise_std
    points = jnp.stack([xs, ys], axis=1)
    return points, labels

# %%
def pred_grid():
    grid_size = 50
    width = 1.5
    x0s, x1s = jnp.meshgrid(
        np.linspace(-width, width, grid_size), np.linspace(-width, width, grid_size)
    )
    xs = np.stack([x0s, x1s]).transpose().reshape((-1, 2))

    return xs

# %%
def true_plot(xs, y):
    df = pd.DataFrame({"x": xs[:, 0], "y": xs[:, 1], "label": y})

    spirals_x_axis = alt.X("x", scale=alt.Scale(domain=[-1.5, 1.5], nice=False))
    spirals_y_axis = alt.Y("y", scale=alt.Scale(domain=[-1.5, 1.5], nice=False))

    spiral_chart = (
        alt.Chart(df, width=350, height=300)
        .mark_circle(stroke="white", size=80, opacity=1)
        .encode(x=spirals_x_axis, y=spirals_y_axis, color=alt.Color("label:N"))
    )

    return spiral_chart

# %%
def prediction_plot(xs, y):
    data = {"x": xs[:, 0], "y": xs[:, 1], "pred": np.exp(y)[:, 1]}
    df = pd.DataFrame(data)
    spirals_x_axis = alt.X("x", scale=alt.Scale(domain=[-1.5, 1.5], nice=False))
    spirals_y_axis = alt.Y("y", scale=alt.Scale(domain=[-1.5, 1.5], nice=False))
    pred_chart = (
        alt.Chart(df, width=350, height=300, title="Predictions from MLP")
        .mark_square(size=50, opacity=1)
        .encode(
            x=spirals_x_axis,
            y=spirals_y_axis,
            color=alt.Color("pred", scale=alt.Scale(scheme="blueorange")),
        )
    )

    return pred_chart

# %%
points, labels = make_spirals(dataset_size, noise_std=0.05)

# %%
spiral_chart = true_plot(points, labels)
spiral_chart
# Out:
# alt.Chart(...)

# %% [markdown]
# # Torch

# %%
class TorchModel(nn.Module):
    def __init__(self, hidden_size: int, num_layers: int):
        super(TorchModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        self.stack = nn.Sequential(
            nn.Linear(2, hidden_size),
            nn.ReLU(),
            *(nn.Linear(hidden_size, hidden_size), nn.ReLU()) * (num_layers - 1),
            nn.Linear(hidden_size, 2),
            nn.LogSoftmax(dim=1),
        )

    def forward(self, x):
        return self.stack(x)

# %% [markdown]
# ## Create torch model

# %%
torch_models = [TorchModel(hidden_size, num_layers) for _ in range(swarm_size)]
torch_optimizers = [
    torch.optim.Adam(torch_model.parameters(), lr=lr) for torch_model in torch_models
]

# %%
# Set torch to use GPU if available
device = torch.device("cpu")
if GPU and torch.cuda.is_available():
    device = torch.device("cuda")
    for torch_model in torch_models:
        torch_model.to(device)

# %%
# Convert to torch tensors
X_train_torch = torch.from_numpy(np.array(points)).float()
y_train_torch = torch.from_numpy(np.array(labels))

# %%
# Move to GPU if available
if GPU:
    X_train_torch = X_train_torch.to(device)
    y_train_torch = y_train_torch.to(device)

# %% [markdown]
# ## Train torch model

# %%
start = time()
for torch_model, torch_optimizer in zip(torch_models, torch_optimizers):
    torch_model.train()
    for epoch in range(epochs):
        torch_optimizer.zero_grad()
        y_pred = torch_model(X_train_torch)
        loss = torch.nn.functional.cross_entropy(y_pred, y_train_torch)
        loss.backward()
        torch_optimizer.step()

        if epoch % 100 == 0:
            print(f"Epoch {epoch} loss: {loss.item()}")

print(f"torch time: {time() - start}")
# Out:
# Epoch 0 loss: 0.6828737854957581
# Epoch 100 loss: 0.6152295470237732
# Epoch 200 loss: 0.481781929731369
# Epoch 300 loss: 0.43467628955841064
# Epoch 400 loss: 0.40698665380477905
# Epoch 500 loss: 0.35786542296409607
# Epoch 600 loss: 0.28868746757507324
# Epoch 700 loss: 0.21677570044994354
# Epoch 800 loss: 0.13285386562347412
# Epoch 900 loss: 0.09474566578865051
# Epoch 1000 loss: 0.08112376183271408
# Epoch 1100 loss: 0.07077959924936295
# Epoch 1200 loss: 0.06130019202828407
# Epoch 1300 loss: 0.05346008390188217
# Epoch 1400 loss: 0.04405168071389198
# Epoch 1500 loss: 0.03755630925297737
# Epoch 1600 loss: 0.03350276127457619
# Epoch 1700 loss: 0.029528360813856125
# Epoch 1800 loss: 0.025065308436751366
# Epoch 1900 loss: 0.021160736680030823
# Epoch 2000 loss: 0.01766040548682213
# Epoch 2100 loss: 0.011051957495510578
# Epoch 2200 loss: 0.00791778415441513
# Epoch 2300 loss: 0.005935355555266142
# Epoch 2400 loss: 0.004643777385354042
# Epoch 2500 loss: 0.0037033907137811184
# Epoch 2600 loss: 0.0030174434650689363
# Epoch 2700 loss: 0.002497253939509392
# Epoch 2800 loss: 0.0020895926281809807
# Epoch 2900 loss: 0.001772834686562419
# Epoch 3000 loss: 0.0015170973492786288
# Epoch 3100 loss: 0.0013130364241078496
# Epoch 3200 loss: 0.0011404327815398574
# Epoch 3300 loss: 0.0009957399452105165
# Epoch 3400 loss: 0.0008749457192607224
# Epoch 3500 loss: 0.0007726809126324952
# Epoch 3600 loss: 0.0006860302528366446
# Epoch 3700 loss: 0.0006124460487626493
# Epoch 3800 loss: 0.00054765964159742
# Epoch 3900 loss: 0.000492135644890368
# Epoch 4000 loss: 0.0004438576870597899
# Epoch 4100 loss: 0.00040146466926671565
# Epoch 4200 loss: 0.0003641192161012441
# Epoch 4300 loss: 0.00033085537143051624
# Epoch 4400 loss: 0.000301001884508878
# Epoch 4500 loss: 0.0002739351475611329
# Epoch 4600 loss: 0.0002496499218977988
# Epoch 4700 loss: 0.00021788862068206072
# Epoch 4800 loss: 0.00019586540292948484
# Epoch 4900 loss: 0.00017805903917178512
# Epoch 5000 loss: 0.000162688666023314
# Epoch 5100 loss: 0.00014890142483636737
# Epoch 5200 loss: 0.00013689923798665404
# Epoch 5300 loss: 0.00012618725304491818
# Epoch 5400 loss: 0.00011664594785543159
# Epoch 5500 loss: 0.0001079822177416645
# Epoch 5600 loss: 0.00010027783719124272
# Epoch 5700 loss: 9.325290739070624e-05
# Epoch 5800 loss: 8.674780838191509e-05
# Epoch 5900 loss: 8.084238652372733e-05
# Epoch 6000 loss: 7.544145046267658e-05
# Epoch 6100 loss: 7.047368853818625e-05
# Epoch 6200 loss: 6.585462688235566e-05
# Epoch 6300 loss: 6.159623444546014e-05
# Epoch 6400 loss: 5.763545777881518e-05
# Epoch 6500 loss: 5.39650754944887e-05
# Epoch 6600 loss: 5.054952998762019e-05
# Epoch 6700 loss: 4.738399729831144e-05
# Epoch 6800 loss: 4.4412579882191494e-05
# Epoch 6900 loss: 4.1674542444525287e-05
# Epoch 7000 loss: 3.908064172719605e-05
# Epoch 7100 loss: 3.6683250073110685e-05
# Epoch 7200 loss: 3.441687294980511e-05
# Epoch 7300 loss: 3.2302956242347136e-05
# Epoch 7400 loss: 3.03367487504147e-05
# Epoch 7500 loss: 2.8506339731393382e-05
# Epoch 7600 loss: 2.6767664166982286e-05
# Epoch 7700 loss: 2.514692096156068e-05
# Epoch 7800 loss: 2.36322248383658e-05
# Epoch 7900 loss: 2.2215219360077754e-05
# Epoch 8000 loss: 2.0886385755147785e-05
# Epoch 8100 loss: 1.9626651919679716e-05
# Epoch 8200 loss: 1.845867336669471e-05
# Epoch 8300 loss: 1.737290949677117e-05
# Epoch 8400 loss: 1.631573832128197e-05
# Epoch 8500 loss: 1.53240926010767e-05
# Epoch 8600 loss: 1.4395610378414858e-05
# Epoch 8700 loss: 1.3530295291275252e-05
# Epoch 8800 loss: 1.272576719202334e-05
# Epoch 8900 loss: 1.1967712453042623e-05
# Epoch 9000 loss: 1.1262097359576728e-05
# Epoch 9100 loss: 1.059580608853139e-05
# Epoch 9200 loss: 9.970038263418246e-06
# Epoch 9300 loss: 9.388368198415264e-06
# Epoch 9400 loss: 8.82934000401292e-06
# Epoch 9500 loss: 8.313219041156117e-06
# Epoch 9600 loss: 7.820934115443379e-06
# Epoch 9700 loss: 7.365597866737517e-06
# Epoch 9800 loss: 6.934099928912474e-06
# Epoch 9900 loss: 6.535974534926936e-06
# torch time: 6.688318967819214

# %% [markdown]
# ## Visualize torch predictions

# %%
xs = pred_grid()

# %%
# Take average of predictions across all models
y = np.zeros((len(torch_models), xs.shape[0], 2))
for idx, model in enumerate(torch_models):
    model.eval()
    with torch.no_grad():
        y_pred = model(torch.from_numpy(xs).float().to(device))
        y[idx] = y_pred.cpu().numpy()

y = np.mean(y, axis=0)

# %%
# Plot predictions
pred_chart = prediction_plot(xs, y)
chart = pred_chart + spiral_chart
chart
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Turba

# %%
def cross_entropy_turba(params, batch, apply_fn):
    log_probs = apply_fn({"params": params}, batch["input"])
    labels = jax.nn.one_hot(batch["output"], log_probs.shape[1])
    loss = -jnp.mean(jnp.sum(labels * log_probs, axis=-1))
    return loss, labels

# %%
class JaxModel(linen.Module):
    hidden_layers: int = 1
    hidden_dim: int = 32

    @linen.compact
    def __call__(self, x):
        for layer in range(self.hidden_layers):
            x = linen.Dense(self.hidden_dim)(x)
            x = linen.relu(x)
        x = linen.Dense(2)(x)
        x = linen.log_softmax(x)
        return x

# %% [markdown]
# ## Create Turba model

# %%
turba_model = JaxModel(hidden_size, num_layers)
turba_state = TurbaTrainState.swarm(turba_model, swarm_size, 2, learning_rate=lr)

# %%
# Set Turba to use GPU if available
if GPU and xla_bridge.get_backend().platform != "gpu":
    raise RuntimeError("GPU support not available for Turba.")

# %% [markdown]
# ## Train Turba model

# %%
from turbanet.loss import softmax_cross_entropy

# Convert to jnp arrays
X_train_turba = jnp.array(
    np.expand_dims(points, axis=0).repeat(swarm_size, axis=0), dtype=jnp.float32
)
y_train_turba = jnp.array(np.expand_dims(labels, axis=0).repeat(swarm_size, axis=0))

start = time()
for epoch in range(epochs):
    turba_state, _, loss = turba_state.train(X_train_turba, y_train_turba, softmax_cross_entropy)

    if epoch % 100 == 0:
        print(f"Epoch {epoch} loss: {loss}")

print(f"turba time: {time() - start}")
# Out:
# Epoch 0 loss: [0.68592983]
# Epoch 100 loss: [0.6859298]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 10
#       8 start = time()
#       9 for epoch in range(epochs):
# ---> 10     turba_state, _, loss = turba_state.train(X_train_turba, y_train_turba, cross_entropy_turba)
#      12     if epoch % 100 == 0:
#      13         print(f"Epoch {epoch} loss: {loss}")
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/turbanet/turba_train_state.py:180, in TurbaTrainState.train(self, input_data, output_data, loss_fn)
#     177 if isinstance(output_data, jnp.ndarray):
#     178     output_data = jnp.asarray(output_data)
# --> 180 return train(self, {"input": input_data, "output": output_data}, loss_fn)
#
#     [... skipping hidden 1 frame]
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/api.py:1015, in vmap.<locals>.vmap_f(*args, **kwargs)
#    1012 try:
#    1013   axis_data = batching.AxisData(axis_name, axis_size_, spmd_axis_name,
#    1014                                 explicit_mesh_axis)
# -> 1015   out_flat = batching.batch(
#    1016       flat_fun, axis_data, in_axes_flat,
#    1017       lambda: flatten_axes("vmap out_axes", out_tree(), out_axes)
#    1018   ).call_wrapped(*args_flat)
#    1019 except batching.SpecMatchError as e:
#    1020   out_axes_flat = flatten_axes("vmap out_axes", out_tree(), out_axes)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/linear_util.py:210, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     208 def call_wrapped(self, *args, **kwargs):
#     209   """Calls the transformed function"""
# --> 210   return self.f_transformed(*args, **kwargs)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/interpreters/batching.py:604, in _batch_outer(f, axis_data, in_dims, *in_vals)
#     602 tag = TraceTag()
#     603 with source_info_util.transform_name_stack('vmap'):
# --> 604   outs, trace = f(tag, in_dims, *in_vals)
#     605 with core.ensure_no_leaks(trace): del trace
#     606 return outs
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/interpreters/batching.py:619, in _batch_inner(f, axis_data, out_dim_dests, tag, in_dims, *in_vals)
#     615   in_tracers = map(partial(to_elt, trace, idx), in_vals, in_dims)
#     616   with (core.set_current_trace(trace),
#     617         core.extend_axis_env_nd([(axis_data.name, axis_data.size)]),
#     618         core.add_spmd_axis_names(axis_data.spmd_name)):
# --> 619     outs = f(*in_tracers)
#     621 out_dim_dests = out_dim_dests() if callable(out_dim_dests) else out_dim_dests
#     622 out_vals = map(partial(from_elt, trace, axis_data.size,
#     623                        axis_data.explicit_mesh_axis),
#     624                range(len(outs)), outs, out_dim_dests)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/interpreters/batching.py:339, in flatten_fun_for_vmap(f, store, in_tree, *args_flat)
#     335 @lu.transformation_with_aux2
#     336 def flatten_fun_for_vmap(f: Callable,
#     337                          store: lu.Store, in_tree: PyTreeDef, *args_flat):
#     338   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# --> 339   ans = f(*py_args, **py_kwargs)
#     340   ans, out_tree = tree_flatten(ans, is_leaf=is_vmappable)
#     341   store.store(out_tree)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/linear_util.py:370, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     368 @transformation_with_aux2
#     369 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 370   ans = _fun(*args, **kwargs)
#     371   result_paths = [_clean_keystr_arg_names(path) for path, _ in generate_key_paths(ans)]
#     372   if _store:
#     373     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     374     # the bwd function in a custom_vjp
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/turbanet/turba_train_state.py:47, in train_fn(state, batch, loss_fn)
#      44     return loss_fn(params, batch, state.apply_fn)
#      46 grad_fn = jax.value_and_grad(wrapped_loss_fn, has_aux=True)
# ---> 47 (loss, prediction), grads = grad_fn(state.params, batch)
#      48 state = state.apply_gradients(grads=grads)
#      49 return state, prediction, loss
#
#     [... skipping hidden 1 frame]
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/api.py:472, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     470   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     471 else:
# --> 472   ans, vjp_py, aux = _vjp(
#     473       f_partial, *dyn_args, has_aux=True)
#     474 _check_scalar(ans)
#     475 tree_map(partial(_check_output_dtype_grad, holomorphic), ans)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/api.py:2019, in _vjp(fun, has_aux, *primals)
#    2017 else:
#    2018   flat_fun, out_aux_trees = flatten_fun_nokwargs2(fun, in_tree)
# -> 2019   out_primals, vjp, aux = ad.vjp(flat_fun, primals_flat, has_aux=True)
#    2020   out_tree, aux_tree = out_aux_trees()
#    2021 out_primal_avals = map(shaped_abstractify, out_primals)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/interpreters/ad.py:262, in vjp(traceable, primals, has_aux)
#     260   out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     261 else:
# --> 262   out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#     264 def unbound_vjp(pvals, jaxpr, consts, *cts):
#     265   cts = tuple(ct for ct, pval in zip(cts, pvals) if not pval.is_known())
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/interpreters/ad.py:245, in linearize(traceable, *primals, **kwargs)
#     243 _, in_tree = tree_flatten(((primals, primals), {}))
#     244 jvpfun_flat, out_tree = flatten_fun(jvpfun, in_tree)
# --> 245 jaxpr, out_pvals, consts = pe.trace_to_jaxpr_nounits(jvpfun_flat, in_pvals)
#     246 out_primals_pvals, out_tangents_pvals = tree_unflatten(out_tree(), out_pvals)
#     247 if any(not out_primal_pval.is_known() for out_primal_pval in out_primals_pvals):
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/profiler.py:334, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     331 @wraps(func)
#     332 def wrapper(*args, **kwargs):
#     333   with TraceAnnotation(name, **decorator_kwargs):
# --> 334     return func(*args, **kwargs)
#     335   return wrapper
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py:576, in trace_to_jaxpr_nounits(fun, pvals, instantiate)
#     574 fun = trace_to_subjaxpr_nounits(fun, trace, instantiate, fun.debug_info)
#     575 with core.set_current_trace(trace):
# --> 576   jaxpr, (out_pvals, consts, env) = fun.call_wrapped(pvals)
#     577   assert not env
#     578 del trace, fun
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/linear_util.py:210, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     208 def call_wrapped(self, *args, **kwargs):
#     209   """Calls the transformed function"""
# --> 210   return self.f_transformed(*args, **kwargs)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py:590, in trace_to_subjaxpr_nounits(f, trace, instantiate, debug_info, in_pvals)
#     582 @lu.transformation2
#     583 def trace_to_subjaxpr_nounits(
#     584     f: Callable,
#    (...)    587     debug_info: core.DebugInfo,
#     588     in_pvals: Sequence[PartialVal]):
#     589   assert all(isinstance(pv, PartialVal) for pv in in_pvals), in_pvals
# --> 590   out_tracers, jaxpr, out_consts, env = _trace_to_subjaxpr_nounits(
#     591       f, trace, instantiate, in_pvals, debug_info)
#     592   out_pvals = [t.pval for t in out_tracers]
#     593   del out_tracers
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py:623, in _trace_to_subjaxpr_nounits(f, trace, instantiate, in_pvals, debug_info)
#     621 in_args = merge_lists(in_knowns, in_tracers, in_consts)
#     622 with core.set_current_trace(trace):
# --> 623   ans = f(*in_args)
#     624 assert isinstance(ans, (list, tuple)), (
#     625     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#     626 assert all(isinstance(x, core.Tracer) or core.valid_jaxtype(x) for x in ans), (
#     627     f"Got unexpected return type when tracing function to jaxpr: {ans}")
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/api_util.py:73, in flatten_fun(f, store, in_tree, *args_flat)
#      69 @lu.transformation_with_aux2
#      70 def flatten_fun(f: Callable, store: lu.Store,
#      71                 in_tree: PyTreeDef, *args_flat):
#      72   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# ---> 73   ans = f(*py_args, **py_kwargs)
#      74   ans, out_tree = tree_flatten(ans)
#      75   store.store(out_tree)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/interpreters/ad.py:80, in jvpfun(f, instantiate, transform_stack, primals, tangents)
#      77 ctx = (source_info_util.transform_name_stack('jvp') if transform_stack
#      78        else contextlib.nullcontext())
#      79 with ctx:
# ---> 80   out_primals, out_tangents = f(tag, primals, tangents)
#      81 if type(instantiate) is bool:
#      82   instantiate = [instantiate] * len(out_tangents)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/interpreters/ad.py:129, in jvp_subtrace_aux(f, store, tag, primals, tangents)
#     127 trace = JVPTrace(parent_trace, tag)
#     128 with core.set_current_trace(trace):
# --> 129   ans, aux = f(*(map(partial(maybe_jvp_tracer, trace), primals, tangents)))
#     130 out_primals, out_tangents = unzip2(map(trace.to_primal_tangent_pair, ans))
#     131 aux_primals = [x.primal if isinstance(x, JVPTracer) and x._trace.tag is tag
#     132                else x for x in aux]
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/api_util.py:106, in flatten_fun_nokwargs2(f, store, in_tree, *args_flat)
#     103 @lu.transformation_with_aux2
#     104 def flatten_fun_nokwargs2(f, store, in_tree, *args_flat):
#     105   py_args = tree_unflatten(in_tree, args_flat)
# --> 106   pair = f(*py_args)
#     107   if not isinstance(pair, (list, tuple)) or len(pair) != 2:
#     108     raise TypeError("expected function with aux output to return a two-element "
#     109                     f"tuple, but got type {type(pair)} with value {pair!r}")
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/api_util.py:284, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     282 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     283 assert next(fixed_args_, sentinel) is sentinel
# --> 284 return _fun(*args, **kwargs)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/linear_util.py:370, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     368 @transformation_with_aux2
#     369 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 370   ans = _fun(*args, **kwargs)
#     371   result_paths = [_clean_keystr_arg_names(path) for path, _ in generate_key_paths(ans)]
#     372   if _store:
#     373     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     374     # the bwd function in a custom_vjp
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/turbanet/turba_train_state.py:44, in train_fn.<locals>.wrapped_loss_fn(params, batch)
#      43 def wrapped_loss_fn(params: dict, batch: dict) -> tuple[ArrayImpl, ArrayImpl]:
# ---> 44     return loss_fn(params, batch, state.apply_fn)
#
# Cell In[20], line 2, in cross_entropy_turba(params, batch, apply_fn)
#       1 def cross_entropy_turba(params, batch, apply_fn):
# ----> 2     log_probs = apply_fn({"params": params}, batch["input"])
#       3     labels = jax.nn.one_hot(batch["output"], log_probs.shape[1])
#       4     loss = -jnp.mean(jnp.sum(labels * log_probs, axis=-1))
#
#     [... skipping hidden 1 frame]
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/flax/linen/module.py:2240, in Module.apply(self, variables, rngs, method, mutable, capture_intermediates, *args, **kwargs)
#    2238   method = self.__call__
#    2239 method = _get_unbound_fn(method)
# -> 2240 return apply(
#    2241   method,
#    2242   self,
#    2243   mutable=mutable,
#    2244   capture_intermediates=capture_intermediates,
#    2245 )(variables, *args, **kwargs, rngs=rngs)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/flax/core/scope.py:1079, in apply.<locals>.wrapper(variables, rngs, *args, **kwargs)
#    1074   raise errors.ApplyScopeInvalidVariablesStructureError(variables)
#    1076 with bind(
#    1077   variables, rngs=rngs, mutable=mutable, flags=flags
#    1078 ).temporary() as root:
# -> 1079   y = fn(root, *args, **kwargs)
#    1080 if mutable is not False:
#    1081   return y, root.mutable_variables()
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/flax/linen/module.py:3022, in apply.<locals>.scope_fn(scope, *args, **kwargs)
#    3020 _context.capture_stack.append(capture_intermediates)
#    3021 try:
# -> 3022   return fn(module.clone(parent=scope, _deep_clone=True), *args, **kwargs)
#    3023 finally:
#    3024   _context.capture_stack.pop()
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/flax/linen/module.py:699, in wrap_method_once.<locals>.wrapped_module_method(*args, **kwargs)
#     697 if args and isinstance(args[0], Module):
#     698   self, args = args[0], args[1:]
# --> 699   return self._call_wrapped_method(fun, args, kwargs)
#     700 else:
#     701   return fun(*args, **kwargs)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/flax/linen/module.py:1216, in Module._call_wrapped_method(self, fun, args, kwargs)
#    1214 if _use_named_call:
#    1215   with jax.named_scope(_derive_profiling_name(self, fun)):
# -> 1216     y = run_fun(self, *args, **kwargs)
#    1217 else:
#    1218   y = run_fun(self, *args, **kwargs)
#
# Cell In[21], line 8, in JaxModel.__call__(self, x)
#       5 @linen.compact
#       6 def __call__(self, x):
#       7     for layer in range(self.hidden_layers):
# ----> 8         x = linen.Dense(self.hidden_dim)(x)
#       9         x = linen.relu(x)
#      10     x = linen.Dense(2)(x)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/flax/linen/module.py:699, in wrap_method_once.<locals>.wrapped_module_method(*args, **kwargs)
#     697 if args and isinstance(args[0], Module):
#     698   self, args = args[0], args[1:]
# --> 699   return self._call_wrapped_method(fun, args, kwargs)
#     700 else:
#     701   return fun(*args, **kwargs)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/flax/linen/module.py:1216, in Module._call_wrapped_method(self, fun, args, kwargs)
#    1214 if _use_named_call:
#    1215   with jax.named_scope(_derive_profiling_name(self, fun)):
# -> 1216     y = run_fun(self, *args, **kwargs)
#    1217 else:
#    1218   y = run_fun(self, *args, **kwargs)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/flax/linen/linear.py:251, in Dense.__call__(self, inputs)
#     241 @compact
#     242 def __call__(self, inputs: Array) -> Array:
#     243   """Applies a linear transformation to the inputs along the last dimension.
#     244
#     245   Args:
#    (...)    249     The transformed input.
#     250   """
# --> 251   kernel = self.param(
#     252     'kernel',
#     253     self.kernel_init,
#     254     (jnp.shape(inputs)[-1], self.features),
#     255     self.param_dtype,
#     256   )
#     257   if self.use_bias:
#     258     bias = self.param(
#     259       'bias', self.bias_init, (self.features,), self.param_dtype
#     260     )
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/flax/linen/module.py:1877, in Module.param(self, name, init_fn, unbox, *init_args, **init_kwargs)
#    1875   raise errors.NameInUseError('param', name, self.__class__.__name__)
#    1876 assert self.scope is not None
# -> 1877 v = self.scope.param(name, init_fn, *init_args, unbox=unbox, **init_kwargs)
#    1878 self._state.children[name] = 'params'
#    1879 return v
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/flax/core/scope.py:950, in Scope.param(self, name, init_fn, unbox, *init_args, **init_kwargs)
#     944   value = meta.unbox(value)
#     945 # Validate that the shape of the init_fn output is the same as the shape
#     946 # of the existing parameter. This is to make sure that the hparams set up
#     947 # in a Flax Module match the shapes coming in during apply, and if not,
#     948 # catch it with an error message.
#     949 # NOTE: We could consider moving this to `self.`
# --> 950 abs_value = jax.eval_shape(
#     951   lambda: init_fn(random.key(0), *init_args, **init_kwargs)
#     952 )
#     953 abs_value_flat = jax.tree_util.tree_leaves(abs_value)
#     954 value_flat = jax.tree_util.tree_leaves(value)
#
#     [... skipping hidden 1 frame]
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/api.py:2702, in eval_shape(fun, *args, **kwargs)
#    2700 try: hash(fun)
#    2701 except TypeError: fun = partial(fun)
# -> 2702 return jit(fun).eval_shape(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:491, in _make_jit_wrapper.<locals>.eval_shape(*args, **kwargs)
#     489 @api_boundary
#     490 def eval_shape(*args, **kwargs):
# --> 491   p, _ = _infer_params(fun, jit_info, args, kwargs)
#     492   out_s = [None if isinstance(s, UnspecifiedValue) else s for s in p.params['out_shardings']]
#     493   # TODO(yashkatariya): Add `Layout` to SDS.
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:730, in _infer_params(fun, ji, args, kwargs)
#     728 entry = _infer_params_cached(fun, ji, signature, avals, pjit_mesh, resource_env)
#     729 if entry.pjit_params is None:
# --> 730   p, args_flat = _infer_params_impl(
#     731       fun, ji, pjit_mesh, resource_env, dbg, args, kwargs, in_avals=avals)
#     732   if p.attrs_tracked:  # if attrs, don't popoulate the cache
#     733     return p, p.consts + args_flat
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:623, in _infer_params_impl(***failed resolving arguments***)
#     616 in_shardings_flat, in_layouts_flat = _process_in_axis_resources(
#     617     in_shardings_treedef, in_shardings_leaves,
#     618     ji.in_layouts_treedef, ji.in_layouts_leaves,
#     619     in_avals, in_tree, flat_fun.debug_info, device_or_backend_set, have_kwargs)
#     621 attr_token = _attr_token(flat_fun, in_type)
# --> 623 jaxpr, consts, out_avals, attrs_tracked = _create_pjit_jaxpr(
#     624     flat_fun, in_type, attr_token, IgnoreKey(ji.inline))
#     626 if config.mutable_array_checks.value:
#     627   _check_no_aliased_closed_over_refs(dbg, (*jaxpr.consts, *consts), explicit_args)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/linear_util.py:442, in cache.<locals>.memoized_fun(fun, *args)
#     440   fun.populate_stores(stores)
#     441 else:
# --> 442   ans = call(fun, *args)
#     443   if explain and config.explain_cache_misses.value:
#     444     explain(fun, cache is new_cache, cache, key)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/pjit.py:1299, in _create_pjit_jaxpr(***failed resolving arguments***)
#    1297     attrs_tracked = []
#    1298   else:
# -> 1299     jaxpr, global_out_avals, consts, attrs_tracked = pe.trace_to_jaxpr_dynamic(
#    1300         fun, in_type)
#    1301     # assert attr_data is sentinel or attr_data matches attrs_tracked
#    1303 if config.debug_key_reuse.value:
#    1304   # Import here to avoid circular imports
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/profiler.py:334, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     331 @wraps(func)
#     332 def wrapper(*args, **kwargs):
#     333   with TraceAnnotation(name, **decorator_kwargs):
# --> 334     return func(*args, **kwargs)
#     335   return wrapper
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/interpreters/partial_eval.py:2172, in trace_to_jaxpr_dynamic(fun, in_avals, keep_inputs)
#    2170 in_tracers = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
#    2171 with core.set_current_trace(trace):
# -> 2172   ans = fun.call_wrapped(*in_tracers)
#    2174 out_tracers = map(trace.to_jaxpr_tracer, ans)
#    2175 _check_no_returned_refs(fun.debug_info, out_tracers)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/linear_util.py:210, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     208 def call_wrapped(self, *args, **kwargs):
#     209   """Calls the transformed function"""
# --> 210   return self.f_transformed(*args, **kwargs)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/api_util.py:284, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     282 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     283 assert next(fixed_args_, sentinel) is sentinel
# --> 284 return _fun(*args, **kwargs)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/api_util.py:73, in flatten_fun(f, store, in_tree, *args_flat)
#      69 @lu.transformation_with_aux2
#      70 def flatten_fun(f: Callable, store: lu.Store,
#      71                 in_tree: PyTreeDef, *args_flat):
#      72   py_args, py_kwargs = tree_unflatten(in_tree, args_flat)
# ---> 73   ans = f(*py_args, **py_kwargs)
#      74   ans, out_tree = tree_flatten(ans)
#      75   store.store(out_tree)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/linear_util.py:370, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     368 @transformation_with_aux2
#     369 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 370   ans = _fun(*args, **kwargs)
#     371   result_paths = [_clean_keystr_arg_names(path) for path, _ in generate_key_paths(ans)]
#     372   if _store:
#     373     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     374     # the bwd function in a custom_vjp
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/flax/core/scope.py:951, in Scope.param.<locals>.<lambda>()
#     944   value = meta.unbox(value)
#     945 # Validate that the shape of the init_fn output is the same as the shape
#     946 # of the existing parameter. This is to make sure that the hparams set up
#     947 # in a Flax Module match the shapes coming in during apply, and if not,
#     948 # catch it with an error message.
#     949 # NOTE: We could consider moving this to `self.`
#     950 abs_value = jax.eval_shape(
# --> 951   lambda: init_fn(random.key(0), *init_args, **init_kwargs)
#     952 )
#     953 abs_value_flat = jax.tree_util.tree_leaves(abs_value)
#     954 value_flat = jax.tree_util.tree_leaves(value)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/nn/initializers.py:336, in variance_scaling.<locals>.init(key, shape, dtype)
#     333 if jnp.issubdtype(dtype, jnp.floating):
#     334   # constant is stddev of standard normal truncated to (-2, 2)
#     335   stddev = jnp.sqrt(variance) / jnp.array(.87962566103423978, dtype)
# --> 336   return random.truncated_normal(key, -2, 2, shape, dtype) * stddev
#     337 else:
#     338   # constant is stddev of complex standard normal truncated to 2
#     339   stddev = jnp.sqrt(variance) / jnp.array(.95311164380491208, dtype)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/random.py:857, in truncated_normal(key, lower, upper, shape, dtype)
#     854   raise ValueError(f"dtype argument to `truncated_normal` must be a float "
#     855                    f"dtype, got {dtype}")
#     856 dtype = dtypes.canonicalize_dtype(dtype)
# --> 857 return _truncated_normal(key, lower, upper, shape, dtype)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/random.py:873, in _truncated_normal(key, lower, upper, shape, dtype)
#     871 if not jnp.issubdtype(dtype, np.floating):
#     872   raise TypeError("truncated_normal only accepts floating point dtypes.")
# --> 873 u = uniform(key, shape, dtype, minval=a, maxval=b)
#     874 out = sqrt2 * lax.erf_inv(u)
#     875 # Clamp the value to the open interval (lower, upper) to make sure that
#     876 # rounding (or if we chose `a` for `u`) doesn't push us outside of the range.
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/random.py:405, in uniform(key, shape, dtype, minval, maxval)
#     402   raise ValueError(f"dtype argument to `uniform` must be a float dtype, "
#     403                    f"got {dtype}")
#     404 dtype = dtypes.canonicalize_dtype(dtype)
# --> 405 return _uniform(key, shape, dtype, minval, maxval)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/random.py:438, in _uniform(key, shape, dtype, minval, maxval)
#     432   bits = lax.convert_element_type(bits, uint_dtype)
#     434 # The strategy here is to randomize only the mantissa bits with an exponent of
#     435 # 1 (after applying the bias), then shift and scale to the desired range. The
#     436 # bit-level transformation we use relies on Numpy and XLA having bit-for-bit
#     437 # equivalent float representations, which might not be true on all platforms.
# --> 438 float_bits = lax.bitwise_or(
#     439     lax.shift_right_logical(bits, np.array(rng_bits - nmant, uint_dtype)),
#     440     np.array(1.0, dtype).view(uint_dtype),
#     441 )
#     442 floats = lax.bitcast_convert_type(float_bits, dtype) - np.array(1., dtype)
#     443 return lax.max(
#     444     minval,
#     445     lax.reshape(floats * (maxval - minval) + minval, shape))
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/lax/lax.py:990, in bitwise_or(x, y)
#     966 @export
#     967 def bitwise_or(x: ArrayLike, y: ArrayLike) -> Array:
#     968   r"""Elementwise OR: :math:`x \vee y`.
#     969
#     970   This function lowers directly to the `stablehlo.or`_ operation.
#    (...)    988   .. _stablehlo.or: https://openxla.org/stablehlo/spec#or
#     989   """
# --> 990   return or_p.bind(x, y)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/core.py:502, in Primitive.bind(self, *args, **params)
#     500 def bind(self, *args, **params):
#     501   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 502   return self._true_bind(*args, **params)
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/core.py:507, in Primitive._true_bind(self, *args, **params)
#     504 def _true_bind(self, *args, **params):
#     505   for arg in args:
#     506     if (isinstance(arg, Tracer)
# --> 507         and not arg._trace.is_valid()
#     508         and not config.data_dependent_tracing_fallback.value):
#     509       raise escaped_tracer_error(arg)
#     510   # TODO: figure out how to handle function arguments
#     511   # assert (not config.enable_checks.value or
#     512   #         all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
#    (...)    515   # is called frequently and it's slightly faster to avoid using a context
#     516   # manager object.
#
# File ~/projects/AAI590-final-project/.venv/lib/python3.12/site-packages/jax/_src/core.py:629, in Trace.is_valid(self)
#     628 def is_valid(self):
# --> 629   return not hasattr(self, "_invalidated")
#
# KeyboardInterrupt:

# %% [markdown]
# ## Visualize turba predictions

# %%
xs = pred_grid()
xs = jnp.array(np.expand_dims(xs, axis=0).repeat(swarm_size, axis=0), dtype=jnp.float32)
xs.shape
# Out:
# (1, 2500, 2)

# %%
# Take average of predictions across all models
y = turba_state.predict(xs)
y = np.mean(y, axis=0)

# %%
xs.shape
# Out:
# (1, 2500, 2)

# %%
xs = np.array(xs[0])
y = np.array(y)

# %%
# Plot predictions
pred_chart = prediction_plot(xs, y)
chart = pred_chart + spiral_chart
chart
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Jax

# %%
classifier_fns = JaxModel()

# %%
optimizer = optax.adam(learning_rate=lr)

# %%
def cross_entropy(logprobs, labels):
    one_hot_labels = jax.nn.one_hot(labels, logprobs.shape[1])
    return -jnp.mean(jnp.sum(one_hot_labels * logprobs, axis=-1))

# %%
def loss_fn(params, batch):
    logits = classifier_fns.apply({"params": params}, batch[0])
    loss = jnp.mean(cross_entropy(logits, batch[1]))
    return loss, logits


loss_and_grad_fn = jax.value_and_grad(loss_fn, has_aux=True)

# %%
def init_fn(input_shape, seed):
    rng = jr.PRNGKey(seed)
    dummy_input = jnp.ones((1, input_shape))
    params = classifier_fns.init(rng, dummy_input)["params"]
    opt_state = optimizer.init(params)
    return params, opt_state

# %%
@jax.jit
def train_step_fn(params, opt_state, batch):
    (loss, grad), output = loss_and_grad_fn(params, batch)
    updates, opt_state = optimizer.update(grad, opt_state)
    params = optax.apply_updates(params, updates)
    return params, opt_state, loss, output

# %%
parallel_init_fn = jax.vmap(init_fn, in_axes=(None, 0))
parallel_train_step_fn = jax.vmap(train_step_fn, in_axes=(0, 0, None))

# %% [markdown]
# ## Create Jax Model

# %%
seeds = jnp.linspace(0, swarm_size - 1, swarm_size).astype(int)
model_states, opt_states = parallel_init_fn(2, seeds)

# %% [markdown]
# ## Train Jax model

# %%
start = time()
for i in range(epochs):
    model_states, opt_states, _ = parallel_train_step_fn(
        model_states, opt_states, (points, labels)
    )

print(f"jax time: {time() - start}")
